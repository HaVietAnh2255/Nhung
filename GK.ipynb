# %% [markdown]
# # Phần 2 : Thực hành

# %% [markdown]
# ## 2.1 Linear Regression(1)

# %% [markdown]
# ##### Câu 1 (4đ) :

# %% [markdown]
# a. Mô tả về tập dữ liệu, vẽ biểu đồ thể hiện mối quan hệ giữa từng biến và biến đầu ra

# %%
# Start

# %% [markdown]
# b. Đề xuất các trường dữ liệu sẽ được sử dụng để huấn luyện mô hình và giải thích ý nghĩa lựa chọn.

# %%
# Start

# %% [markdown]
# c. Thay thế các giá trị bị khuyết thiếu trong tập dữ liệu bằng giá trị trung vị của cột đó.
# In ra bảng sau khi đã thay đổi :

# %%
# Start

# %% [markdown]
# d. Chuẩn hóa dữ liệu thành dạng z-core (standardization) theo công thức :
# #### Z  = (Giá trị - Trung bình) / độ lệch chuẩn

# %%
def normalize():
    # TODO : implement z-score normalization
    pass

# %% [markdown]
# ### Câu 2 (4đ):

# %% [markdown]
# a. Xây dựng hàm mất mát MSE

# %%
def MSE(y_pred, y_true):
    # TODO: implement MSE
    pass

# %% [markdown]
# b. Cài đặt thuật toán tối ưu Gradient Descent

# %%
def gradient_descent(X, y, weights, learning_rate, iterations):
    # TODO : implement gradient descent
    pass

# %% [markdown]
# c. Thực hiện huấn luyện mô hình với tham số tùy chỉnh và vẽ đồ thị thể hiện sự thay đổi của loss qua từng vòng lặp.

# %%
def train(X, y, learning_rate, iterations):
    # TODO : implement model fitting
    pass

# %% [markdown]
# d. Thêm vào hệ số phạt L2, thực hiện huấn luyện lại mô hình

# %%
def train_with_L2_regularization(X, y, learning_rate, iterations, lamda_reg):
    # TODO : implement L2 regularization
    pass

# %% [markdown]
# ### Câuu 3 (2đ) :

# %% [markdown]
# a. Xây dựng công thức và đánh giá mô hình thông qua chỉ số MAE, RMSE, R2 score

# %%
def evaluate(y_true, y_pred):
    mae = ...
    rmse = ...
    r2_score = ...
    return mae, rmse, r2_score

# %% [markdown]
# b. Thực hiện dự đoán điểm cuối kỳ của một bạn học sinh thông qua các trường dữ liệu đã lựa chọn để train.

# %%
def prediction(X, weights):
    # TODO : implement prediction
    pass

# %% [markdown]
# ## Linear Regression (2)

# %% [markdown]
# ### Câu 1 (4đ) :

# %% [markdown]
# a. Mô tả về tập dữ liệu, tạo một cột total bằng tổng các cột math_score, reading_score, writing_score.

# %%
# Start

# %% [markdown]
# b. Vẽ biểu đồ thể hiện mối quan hệ giữa từng biến và biến đầu ra (total)

# %%
# Start

# %% [markdown]
# c. Đề xuất các trường dữ liệu sẽ được sử dụng để huấn luyện mô hình và giải thích lý do tại sao lựa chọn.

# %%
# Trả lời

# %% [markdown]
# d. Chuẩn hóa dữ liệu thành dạng min-max scaler theo công thức :
# #### Z = (X - Xmin) / (Xmax -Xmin)

# %%
def normalize():
    # TODO : implenment z scaler
    pass

# %% [markdown]
# ### Câu 2 (4đ) :

# %% [markdown]
# a. Xây dựng hàm mất mát MSE và giải thích ý nghĩa của hàm này trong bài toán hồi quy.

# %%
def mse_loss(y_true, y_pred):
    # TODO : implenment MSE
    pass

# %% [markdown]
# b. Cài đặt thuật toán tối ưu Gradient Descent

# %%
def gradient_descent(X, y, weights, learning_rate, iterations):
    # TODO : implement gradient descent
    pass

# %% [markdown]
# c. Thực hiện huấn luyện mô hình với tham số tùy chỉnh và vẽ đồ thị thể hiện sự thay đổi của loss qua từng vòng lặp.

# %%
def train(X, y, learning_rate, iterations):
    # TODO : implement tranining logic
    pass

# %% [markdown]
# d. Thêm vào hệ số phạt L1, thực hiện huấn luyện lại mô hình

# %%
def train_with_L1_regularization(X, y, learning_rate, iterations, lamda_reg):
    # TODO : implement L1 regularization
    pass

# %% [markdown]
# ## Câu 3(2đ) :

# %% [markdown]
# a. Xây dựng công thức và đánh giá mô hình thông qua chỉ số MAE, RMSE, R2 score

# %%
def evaluate(y_true, y_pred):
    mae = ...
    rmse = ...
    r2_score = ...
    return mae, rmse, r2_score

# %% [markdown]
# b. Thực hiện dự đoán điểm tổng kết của một bạn học sinh thông qua các trường dữ liệu đã lựa chọn để train.

# %%
def prediction(X, weights):
    # TODO : implement prediction
    pass

# %% [markdown]
# ## 2.3 Logistic Regression(1)

# %% [markdown]
# Câu 1 (4đ):

# %% [markdown]
# a. Đánh giá tổng quan tập dữ liệu, vẽ biểu đồ thể hiện sự phân bố của các lớp.

# %%
# Start

# %% [markdown]
# b. Mã hóa biến đầu ra (diagnosis) thành dạng nhị phân.

# %%
# Start

# %% [markdown]
# c. Nhận xét về tính cân bằng của dữ liệu, xử lý mất cân bằng dữ liệu và nếu rõ phương pháp(nếu có).

# %%
# Start

# %% [markdown]
# d. Chuẩn hóa dữ liệu thành dạng min-max scaler

# %%
def normalize():
    # TODO : implenment z scaler
    pass

# %% [markdown]
# ### Câu 2 (4đ) :

# %% [markdown]
# a. Xây dựng hàm Sigmod

# %%
def sigmod(X):
    # TODO :implement sigmod function
    pass

# %% [markdown]
# b. Xây dựng hàm mất mát Binary Cross Entropy

# %%
def binary_cross_entropy(y_true, y_pred, eps=1e-15):
    # TODO : implement BCE Loss
    pass

# %% [markdown]
# c. Cài đặt thuật toán tối ưu Gradient Descent

# %%
def gradient_descent_logistic(X, y, w, b, lr, n_iters):
    # TODO : implement update w, b theo gradient
    pass

# %% [markdown]
# d. Thực hiện huấn luyện mô hình với tham số tùy chỉnh và vẽ đồ thị thể hiện sự thay đổi của loss qua từng vòng lặp.

# %%
def train_logistic(X, y, lr, n_iters):
    # TODO: implement logistic regression training
    pass

# %% [markdown]
# ### Câu 3 (2đ):

# %% [markdown]
# a. Xây dựng công thức đánh giá mô hình thông qua các chỉ số Accuracy, Precision, Recall

# %%
def evaluate_classification(y_true, y_pred):
    accuracy = None
    precision = None
    recall = None
    return accuracy, precision, recall

# %% [markdown]
# b. Nhận xét về hiệu suất của mô hình dựa trên các chỉ số đã tính toán

# %% [markdown]
# c. Tạo một ca bệnh mới (dummy data) và thực hiện chuẩn đoán.

# %%
# Start

# %% [markdown]
# ## 2.4 Logistic Regression(2)

# %% [markdown]
# ### Câu 1 (4đ) :

# %% [markdown]
# a. Đánh giá tổng quan tập dữ liệu vẽ biểu đồ thể hiện sự phân bố các lớp

# %%
# Start

# %% [markdown]
# b. Lựa chọn các trường dữ liệu để huấn luyện, đưa ra lý do lưa chọn.

# %%
# Start

# %% [markdown]
# c. Nhận xét về tính cân bằng của dữ liệu, xử lý mất cân bằng dữ liệu và nếu rõ phương pháp(nếu có).

# %%
# Start

# %% [markdown]
# d. Chuẩn hóa dữ liệu thành dạng z-score(standardization)

# %%
def normalize(X):
    # TODO : implement z-score
    pass

# %% [markdown]
# ### Câu 2 (3đ) :

# %% [markdown]
# a. Xây dựng hàm Sigmod

# %%
def sigmod(X):
    # TODO :implement sigmod function
    pass

# %% [markdown]
# b. Xây dựng hàm mất mát Binary Cross Entropy

# %%
def binary_cross_entropy(y_true, y_pred, eps=1e-15):
    # TODO : implement BCE Loss
    pass

# %% [markdown]
# c. Cài đặt thuật toán tối ưu Gradient Descent

# %%
def gradient_descent_logistic(X, y, w, b, lr, n_iters):
    # TODO : implement update w, b theo gradient
    pass

# %% [markdown]
# d. Thực hiện huấn luyện mô hình với tham số tùy chỉnh và vẽ đồ thị thể hiện sự thay đổi của loss qua từng vòng lặp.

# %%
def train_logistic(X, y, lr, n_iters):
    # TODO: implement logistic regression training
    pass

# %% [markdown]
# ### Câu 3 (3đ) :

# %% [markdown]
# a. Xây dựng công thức đánh giá mô hình thông qua các chỉ số Accuracy, Precision, Recall

# %%
def evaluate_classification(y_true, y_pred):
    accuracy = None
    precision = None
    recall = None
    return accuracy, precision, recall

# %% [markdown]
# b. Nhận xét về hiệu suất của mô hình dựa trên các chỉ số đã tính toán

# %%
# Start

# %% [markdown]
# c. Tạo một ca bệnh mới (dummy data) và thực hiện chuẩn đoán.

# %%
# Start

# %% [markdown]
# ## 2.5 Softmax Regression(1)

# %% [markdown]
# ### Câu 1 (4đ) :

# %% [markdown]
# a. Đánh giá tổng quan tập dữ liệu, vẽ biểu đồ thể hiện sự phân bố của các lớp

# %%
# Start

# %% [markdown]
# b. Mã hóa biến đầu ra thành dạng one-hot vector

# %%
# Start

# %% [markdown]
# c. Nhận xét về tính cân bằng của dữ liệu, xử lý mất cân bằng dữ liệu và nêu rõ phương pháp (nếu có).

# %%
# Start

# %% [markdown]
# d. Chuẩn hóa dữ liệu thành dạng z-score(standardization)

# %%
def normalize(X):
    # TODO : implement z-score
    pass

# %% [markdown]
# ### Câu 2 (4đ) :

# %% [markdown]
# a. Xây dựng hàm softmax

# %%
def softmax(z):
    """
    Input : z - ma trận đầu vào (N,C)
    Ouput : ma trận xác suất (N,C)
    """
    e_z = np.exp(z - np.max(z, axis=1, keepdims=True))

    # TODO : Cập nhật biến prob để tính xác suất softmax
    prob = ... 

    return prob

# %% [markdown]
# b. Xây dựng hàm mất mát Cross Entropy

# %%
def cross_entropy_loss(y_true, y_pred, eps=1e-15):
    # TODO : implement multiclass cross entropy
    pass

# %% [markdown]
# c. Cài đặt thuật toán tối ưu Gradient Descent

# %%
def gradient_descent_softmax(X, y_onehot, W, b, lr, n_iters):
    # TODO : implement W, b theo gradient
    pass

# %% [markdown]
# d. Thực hiện huấn luyện mô hình với tham số tùy chỉnh và vẽ đồ thị thể hiện sự thay đổi của loss qua từng vòng lặp.

# %%
def train_softmax(X, y, lr, n_iters):
    # TODO : implement softmax regression training
    pass

# %% [markdown]
# ### Câu 3 (2đ):

# %% [markdown]
# a. Xây dựng công thức và đánh giá mô hình thông qua chỉ số Accuracy, Precision, Recall

# %%
def evaluate(y_true, y_pred_labels):
    """
    Tính toán Accuracy, Precision, Recall
    """
    # TODO : Tính toán giá trị TP, FP, TN, FN
    TP = ...
    FP = ...
    FN = ...
    TN = ...

    # TODO : tính các chỉ số
    accuracy = ...
    precision = ...
    recall = ...

    reuturn accuracy, precision, recall

# %% [markdown]
# b. Tạo một dữ liệu mới (dummy data) và thực hiện dự đoán loại vi khuẩn ecoli

# %%
# Start

# %% [markdown]
# ## 2.6 Softmax Regression(2)

# %% [markdown]
# ### Câu 1 (4đ):

# %% [markdown]
# a. Đánh giá tổng quan tập dữ liệu, vẽ biểu đồ thể hiện sự phân bố của các lớp

# %%
# Start

# %% [markdown]
# b. Mã hóa biến đầu ra thành dạng one-hot vector

# %%
# Start

# %% [markdown]
# c. Nhận xét về tính cân bằng của dữ liệu, xử lý mất cân bằng dữ liệu và nêu rõ phương pháp (nếu có).

# %%
# Start

# %% [markdown]
# d. Chuẩn hóa dữ liệu thành dạng min_max scaling

# %%
def normalize(X):
    # TODO : implement min-max scaling
    pass

# %% [markdown]
# ### Câu 2 (4đ):

# %% [markdown]
# a. Xây dựng hàm softmax

# %%
def softmax(z):
    """
    Input : z - ma trận đầu vào (N,C)
    Ouput : ma trận xác suất (N,C)
    """
    e_z = np.exp(z - np.max(z, axis=1, keepdims=True))

    # TODO : Cập nhật biến prob để tính xác suất softmax
    prob = ... 

    return prob

# %% [markdown]
# b. Xây dựng hàm mất mát Cross Entropy

# %%
def cross_entropy_loss(y_true, y_pred, eps=1e-15):
    # TODO : implement multiclass cross entropy
    pass

# %% [markdown]
# c. Cài đặt thuật toán tối ưu Gradient Descent

# %%
def gradient_descent_softmax(X, y_onehot, W, b, lr, n_iters):
    # TODO : implement W, b theo gradient
    pass

# %% [markdown]
# d. Thực hiện huấn luyện mô hình với tham số tùy chỉnh và vẽ đồ thị thể hiện sự thay đổi của loss qua từng vòng lặp.

# %%
def train_softmax(X, y, lr, n_iters):
    # TODO : implement softmax regression training
    pass

# %% [markdown]
# ### Câu 3 (2đ) :

# %% [markdown]
# a. Xây dựng công thức và đánh giá mô hình thông qua chỉ số Accuracy, Precision, Recall

# %%
def evaluate(y_true, y_pred_labels):
    """
    Tính toán Accuracy, Precision, Recall
    """
    # TODO : Tính toán giá trị TP, FP, TN, FN
    TP = ...
    FP = ...
    FN = ...
    TN = ...

    # TODO : tính các chỉ số
    accuracy = ...
    precision = ...
    recall = ...

    reuturn accuracy, precision, recall

# %% [markdown]
# b. Tạo một dữ liệu mới (dummy data) và thực hiện dự đoán loại thủy tinh

# %%
# Start

# %% [markdown]
# ## 2.8 KNN

# %% [markdown]
# ### Câu 1 (4đ):

# %% [markdown]
# a. Mô tả tập dữ liệu và thực hiện mã hóa biến đầu ra về dạng số (nếu cẩn)

# %%
# Start

# %% [markdown]
# b. Đề xuất các trường dữ liệu dùng để huấn luyện và giải thích lý do lựa chọn

# %%
# Start

# %% [markdown]
# c. Chuẩn hóa dữ liệu theo min-max scaling

# %%
def normalize(X):
    # TODO : implement min-max scaling
    pass

# %% [markdown]
# d. Chia tập train/test theo stratify để giữ phân phối lớp ổn định

# %%
# Start

# %% [markdown]
# ### Câu 2 (4đ) :

# %% [markdown]
# a. Cài đặt hài hàm khoảng cách Euclidean và Manhattan

# %%
def euclidean_distance(x1, x2):
    # TODO : implement euclidean distance
    pass
def manhattan_distance(x1, x2):
    # TODO : implement manhattan distance
    pass

# %% [markdown]
# b. Cài đặt KNN cho bài toán đa lớp với cơ chế voting theo số lượng láng giếng gần nhất

# %%
def knn_predict_multiclass(X_train, y_train, X_test, k, metric='euclidean'):
    # TODO : implement multiclass knn predict
    pass

# %% [markdown]
# c. Thử nhiều giá trị k và metric, so sánh kết quả bằng bằng hoặc biểu đồ để chọn cấu hình tốt nhất.

# %%
# Start

# %% [markdown]
# ### Câu 3 (2đ) :

# %% [markdown]
# a. Đánh giá mô hình bằng Accuracy, Precision-marco, Recall- marco và F1-marco

# %%
def evaluate_multiclass(y_true, y_pred):
    accuracy = None
    precision_marco = None
    recall_marco = None
    f1_marco = None
    return accuracy, precision_marco, recall_marco, f1_marco

# %% [markdown]
# b. Tạo một mẫu dữ liệu mới (dummy data) và dự đoán lớp bằng mô hình KNN tốt nhất

# %%
# Start

# %% [markdown]
# ## 2.9 Decision Tree

# %% [markdown]
# ### Câu 1 (4đ):

# %% [markdown]
# a. Khảo sát tập dữ liệu mô tả biến đầu ra và vẽ biểu đồ phân bố lớp

# %%
# Start

# %% [markdown]
# b. Lựa chọn các đặc trưng huấn luyện và giải thích lý do?

# %%
# Start

# %% [markdown]
# c. Tiền xử lý dữ liệu (mã hóa biến phân loại nếu có) và chia tập train/test

# %%
# Start

# %% [markdown]
# ### Câu 2 (4đ):

# %% [markdown]
# a. Cài đặt hàm tính Entropy cho biến mục tiêu

# %%
def entropy(y):
    # TODO : implement entropy
    pass

# %% [markdown]
# b. Cài đặt hàm tính Information-Gain để chọn thuộc tính tách tốt nhất

# %%
def information_gain(X_column, y):
    # TODO : implement information gain
    pass

# %% [markdown]
# c. Huấn luyện mô hình Decision Tree với các siêu tham số max_depth, min_samples_split và đánh giá trên tập test.

# %%
def train_decision_tree(X_train, y_train, max_depth, min_samples_split):
    # TODO : implement model training
    pass

# %% [markdown]
# d. Trực quan hóa cây quyết định hoặc in feature importance và nhận xét.

# %%
# Start

# %% [markdown]
# ### Câu 3 (2đ):

# %% [markdown]
# a. Tính Accuracy , Precision, Recall cho mô hình Decision Tree

# %%
def evaluate(y_true, y_pred):
    accuracy = None
    precision = None
    recall = None
    return accuracy, precision, recall

# %% [markdown]
# b. Tạo một mẫu dữ liệu mới(dummy data) và dự đoán nhãn bằng mô hình đã huấn luyện.

# %%
# Start
